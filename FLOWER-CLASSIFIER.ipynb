# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika00-77/L-T-Task/blob/main/FLOWER-CLASSIFIER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Load the tools
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# 2. Get the data (The 'Iris' dataset is built-in)
data = load_iris()
X, y = data.data, data.target

# 3. Split the data (80% for learning, 20% for testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# 4. Create the "Brain" (The Model)
model = RandomForestClassifier()

# 5. Train the Brain
model.fit(X_train, y_train)

# 6. Test the Brain
predictions = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, predictions) * 100}%")
# Out:
# Accuracy: 96.66666666666667%
